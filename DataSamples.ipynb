# %%
import pandas as pd
import glob

# %%
glob.glob("data/*.*")
# Out:
# ['data\\Apple_job_posting_data.json',
#  'data\\glassdoor_jobs_sample.json',
#  'data\\glassdor_custom.csv',
#  'data\\indeed_data.json',
#  'data\\indeed_job_sample.json',
#  'data\\Job Details USA- Indeed.xlsx',
#  'data\\Job Details- Salary& Benefits- Glassdoor.xlsx',
#  'data\\li_jobs.zip',
#  'data\\ResumeDataSet.csv']

# %%
df = pd.read_json('data/Apple_job_posting_data.json')

# %%
df.job_description.apply(lambda x: len(x))
# Out:
# 0      394
# 1      484
# 2      874
# 3      702
# 4      829
# 5        1
# 6        1
# 7        1
# 8      622
# 9        1
# 10     554
# 11     543
# 12       1
# 13       1
# 14     731
# 15     657
# 16     634
# 17     551
# 18     794
# 19     618
# 20     716
# 21     874
# 22     418
# 23       1
# 24     481
# 25     531
# 26     462
# 27    2260
# 28     874
# 29       1
# 30       1
# 31       1
# 32     968
# 33     308
# 34     506
# 35     488
# 36     665
# 37     874
# 38     482
# 39       1
# 40     377
# 41     511
# 42     874
# 43     921
# 44     411
# 45     616
# 46     682
# 47     669
# 48     890
# 49     825
# Name: job_description, dtype: int64

# %%
df.iloc[1]
# Out:
# city                                                                 -
# category                                                 Teaching Jobs
# remote                                                               0
# job_description      As a Creative, your main role at the Apple Sto...
# contract_time                                                full_time
# salary_min                                                           -
# salary_max                                                           -
# geo_lng                                                    -100.445882
# job_id               01249cb19a65c655a2240254583eace82f7aea7f8b478b...
# job_location                                             United States
# job_title                                                  US-Creative
# company_name                                                Apple Inc.
# salary_frequency                                                     -
# ...

# %%
df = pd.read_json('data/indeed_data.json')

# %%
df
# Out:
#                               city                   category  remote  \
# 0                                -                Retail Jobs       0
# 1                                -              Teaching Jobs       0
# 2   Santa Clara Valley (Cupertino)           Engineering Jobs       0
# 3                    United States                 Sales Jobs       0
# 4                                -                Retail Jobs       0
# 5                                -                  "IT Jobs"       0
# 6                                -         "Engineering Jobs"       0
# 7                                -         "Engineering Jobs"       0
# 8                                -                    IT Jobs       0
# 9                                -         "Engineering Jobs"       0
# 10                       Cupertino                    IT Jobs       0
# 11                          Austin                    IT Jobs       0
# ...

# %%
df.job_description.apply(lambda x: len(x))
# Out:
# 0      394
# 1      484
# 2      874
# 3      702
# 4      829
# 5        1
# 6        1
# 7        1
# 8      622
# 9        1
# 10     554
# 11     543
# 12       1
# 13       1
# 14     731
# 15     657
# 16     634
# 17     551
# 18     794
# 19     618
# 20     716
# 21     874
# 22     418
# 23       1
# 24     481
# 25     531
# 26     462
# 27    2260
# 28     874
# 29       1
# 30       1
# 31       1
# 32     968
# 33     308
# 34     506
# 35     488
# 36     665
# 37     874
# 38     482
# 39       1
# 40     377
# 41     511
# 42     874
# 43     921
# 44     411
# 45     616
# 46     682
# 47     669
# 48     890
# 49     825
# Name: job_description, dtype: int64

# %%
df.iloc[5]
# Out:
# city                                                                 -
# category                                                     "IT Jobs"
# remote                                                               0
# job_description                                                      -
# contract_time                                                full_time
# salary_min                                                           -
# salary_max                                                           -
# geo_lng
# job_id               019c6c288bc627a7c789db77283cc4bfbf39a310f11d5c...
# job_location                                                         -
# job_title                                                            -
# company_name                                                Apple Inc.
# salary_frequency                                                     -
# salary_currency                                                      -
# geo_lat
# ...

# %%
df = pd.read_excel('data/Job Details USA- Indeed.xlsx')

# %%
df
# Out:
#                                             Job Title  \
# 0      Assistant Bookkeeper / Secretary /Receptionist
# 1                         Server, Bartender, and Host
# 2   Customer Service Team Member - Start at $15-$1...
# 3   Facility Operator I-IV Coronado Generating Sta...
# 4                                   Commercial Roofer
# ..                                                ...
# 94        Protective Services Helpline Representative
# 95                       Bookkeeping Office Assistant
# 96            Process Engineer - Wells & Pads NOR Job
# 97                          Quality Assurance Analyst
# 98             Customer Service Representative REMOTE
#
#                                               Job URL Job Search Letter  \
# 0   https://www.indeed.com/viewjob?viewtype=embedd...                 A
# 1   https://www.indeed.com/viewjob?viewtype=embedd...                 B
# 2   https://www.indeed.com/viewjob?viewtype=embedd...                 C
# ...

# %%
df['Job Description'].apply(lambda x: len(x))
# Out:
# 0     3141
# 1      360
# 2     2856
# 3     3088
# 4     1622
#       ...
# 94    2646
# 95    3555
# 96    5860
# 97    4555
# 98    2486
# Name: Job Description, Length: 99, dtype: int64

# %%
df['Job Description'].iloc[5]
# Out:
# "\n The Pond Guy's Marketing Team continues to grow and look for talent. We currently have 13 top-performers on our team, several who joined in the last 2 years. Not only do we grow together, but we also stay together. We have had 100% retention for 5 years! The key to that success is culture. Our team is positive, collaborative, and well-resourced with the latest technology. Additionally, we work on a wide variety of interesting projects.\n  Looking for positive growth opportunities? Well, we're looking for you. Apply today!\n  Job Description\n  Our Copywriter creates and edits engaging content that is disseminated across various channels. These channels may include print, digital, email and/or social. In this role, you will be responsible for creating and proofing marketing materials, product descriptions, direct email and articles, technical manuals, labels, scripts and social media content. The ideal candidate must possess a keen understanding of customer demographics and needs 
# ...

# %%
 'data\\Job Details USA- Indeed.xlsx',
 'data\\Job Details- Salary& Benefits- Glassdoor.xlsx',

# %%
df = pd.read_excel('data/Job Details- Salary& Benefits- Glassdoor.xlsx')

# %%
df
# Out:
#    Country             Company Name  Job Id  \
# 0      USA  Boston Consulting Group  660263
# 1      USA                Strategy&   47253
# 2      USA       McKinsey & Company   31772
# 3      USA           Bain & Company   31772
# 4      USA            Roland Berger   47253
# ..     ...                      ...     ...
# 94     USA        L.E.K. Consulting  772506
# 95     USA                  Kearney   60807
# 96     USA             Oliver Wyman   57858
# 97     USA  Boston Consulting Group   11318
# 98     USA                Strategy&   31232
#
#                                  Position LevelOfTrust  AverageSalary  \
# 0                               Senior VP    CONFIDENT         564456
# 1                                 Partner    CONFIDENT         464023
# 2                                     EVP    CONFIDENT         820682
# 3                                     EVP    CONFIDENT         823754
# 4                                 Partner    CONFIDENT         480853
# ...
