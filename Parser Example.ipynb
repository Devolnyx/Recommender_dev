# %%
import pandas as pd, numpy as np

# %%
df = pd.read_csv('data/glassdor_custom.csv')

# %%
print(df.Description.iloc[11])
# Out:
# Bachelor’s Degree from an accredited college or university required, preferably in marketing, advertising or related field. Medical coverage on date of hire.…

# %%
df.Description.apply(lambda x: len(x))
# Out:
# 0       157
# 1       160
# 2       160
# 3       157
# 4       155
#        ...
# 1225    162
# 1226    155
# 1227    161
# 1228    155
# 1229    158
# Name: Description, Length: 1230, dtype: int64

# %%
df.Description.apply(lambda x: len(x)).max()
# Out:
# 162

# %%
df.jobcard_seolink_wdqhz_URL.iloc[10]
# Out:
# 'https://www.glassdoor.com/job-listing/channel-marketing-manager-remote-crowdstrike-JV_KO0,32_KE33,44.htm?jl=1008945134751'

# %%
from lxml import html, etree
import requests
import re
import os
import sys
#import unicodecsv as csv
import argparse
import json
import urllib
from urllib.request import urlopen, Request
from urllib.parse import urlparse
from bs4 import BeautifulSoup as soup

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:121.0) Gecko/20100101 Firefox/121.0', 
           'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
           'Accept-Charset': 'ISO-8859-1,utf-8;q=0.7,*;q=0.3',
           'Accept-Encoding': 'gzip, deflate, br',
           'Accept-Language': 'en-US;q=0.5,en;q=0.3',
           'Connection': 'keep-alive'
           }
proxy_support = urllib.request.ProxyHandler({'http': 'http://65.109.231.57:8080'})
opener = urllib.request.build_opener(proxy_support)
urllib.request.install_opener(opener)
request_obj = Request(url='https://www.glassdoor.com/Job/data-engineer-jobs-SRCH_KO0,13.htm', headers=headers)
opened_url = urlopen(request_obj)
page_html = opened_url.read()
opened_url.close()
page_soup = soup(page_html, "html.parser")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In [21], line 12
#      10 urllib.request.install_opener(opener)
#      11 request_obj = Request(url='https://www.glassdoor.com/Job/data-engineer-jobs-SRCH_KO0,13.htm', headers=headers)
# ---> 12 opened_url = urlopen(request_obj)
#      13 page_html = opened_url.read()
#      14 opened_url.close()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
# ...

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:121.0) Gecko/20100101 Firefox/121.0', 
           'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
           'Accept-Charset': 'ISO-8859-1,utf-8;q=0.7,*;q=0.3',
           'Accept-Encoding': 'gzip, deflate, br',
           'Accept-Language': 'en-GB,en-US;q=0.8,en;q=0.6',
           'Connection': 'keep-alive'
           }
proxy_support = urllib.request.ProxyHandler({'http': 'http://65.109.231.57:8080'})
opener = urllib.request.build_opener(proxy_support)
urllib.request.install_opener(opener)
request_obj = Request(url='https://www.zenrows.com/blog/403-web-scraping#set-fake-user-agent', headers=headers)
opened_url = urlopen(request_obj)
page_html = opened_url.read()
opened_url.close()
page_soup = soup(page_html, "html.parser")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In [26], line 12
#      10 urllib.request.install_opener(opener)
#      11 request_obj = Request(url='https://www.zenrows.com/blog/403-web-scraping#set-fake-user-agent', headers=headers)
# ---> 12 opened_url = urlopen(request_obj)
#      13 page_html = opened_url.read()
#      14 opened_url.close()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
# ...

# %%
#https://console.apify.com/actors/y76kbieXjdDLfUDQ7/runs/82aYFwpUbE6j9fnCB#output
# Out:
# S��R�z)�oZ���G!y-�0׈�����eB��j@������
#
# ����j�;�.�������j����S�&amp;3�6��&amp;�۔�Ȏ�~'����y�!@/
# �wIx^��=�����ޛ�D
# ��h4��1��]z��`.�L��F�2�Z�ۻ��V^�Y��3B�;�I
# ��%=9���t�C?g����2�EXG,�x���1&amp;�
# �73
# ޟ����r
# &gt;kP��S��_Z�2���i�$�
# ��&lt;8rԉFH��D
# ���&amp;
# ���&amp;���N�k[��J�jny��~������,:E�H�
# J��{����A���	H�}(�&amp;.��\$Ϥ���pR�޶9Y�4N-;��V�RW9Y,��{�e*���(u�đ#G����w��]���+�*͎��
# �k�
# x��������j���F���5&amp;���t�C%�v�
# 9����#'�������R�~r�զ��5�*ùrI�\4�9��k?
# ��&lt; (��Hb
# ��
# Un�������/�����5��@Y���m�e����
# x q*�
# �վ_45:�gw�(��k�{��g
# F"ׇ8����&amp;D��A�eզ�}f��������$w�a���[�(jRŬ]ƴ������6����.�EM��着�$��W�{��!z�,��v�����!v%f����l�
# � ""�fm��j̨j����]p��^���U�����D49�
# �	�JH,7�	�?�mU�[N����
# 9�I�9�؇7�
# �H�A�8K��������� �x&lt;��c9�L��]�
# �)�El&amp;�t\o�;����v�V�(��[L���
# v�����T
# �Ӳ(��m����ܬ���֪�~/��}���L��%�w��]����
# ���i�{2�,s3�
#
# �*(-S
# UVA�m�([�4
# ћ-J�0��c�f���zJHJ�#=����w���?!#67�s.�D���b�T}_��\)��a;��Q{j�����nn��$�T%��!A��պF){&lt;^�&amp;'ؤi�
# ...
